# %%
### Importando librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as ptl
import seaborn as sns
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import requests
from bs4 import BeautifulSoup 
import requests
import re
import urllib.request, urllib.parse, urllib.error
from urllib.request import urlopen

# %%
url="https://www.uniprot.org"
uclient=urlopen(url)
pagehtml=uclient.read()
uclient.close()
print(pagehtml)
# Out:
# b'<!DOCTYPE html SYSTEM "about:legacy-compat">\n<html xmlns="http://www.w3.org/1999/xhtml" lang="en" xml:lang="en"><head><title>UniProt</title><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"/><meta content="width=device-width, initial-scale=1" name="viewport"/><link href="/" rel="home"/><link href="https://creativecommons.org/licenses/by/4.0/" rel="license"/><link type="image/vnd.microsoft.icon" href="/favicon.ico" rel="shortcut icon"/><link href="/uniprot.min.css2021_02" type="text/css" rel="stylesheet"/><link href="/tippy.css" type="text/css" rel="stylesheet"/><script type="text/javascript">\n\t\t\tvar BASE = \'/\';\n\t\t</script><script src="/js-compr.js2021_02" type="text/javascript"></script><script type="text/javascript">\n\t\t\t\tuniprot.isInternal = false;\n\t\t\t\tuniprot.namespace = \'uniprot\';\n\t\t\t\tuniprot.releasedate = \'2021_02\';\n\t\t\t</script><script type="text/javascript">\n\t\t\t;\n\t\t</
# ...

# %%
genes = ["TRNAG-UCC" , "ROBO1","TRNAC-GCA","TRNAC-ACA","MIR2286","LOC101910021","LOC112447295","CD47","IFT57","HHLA2",
         "MYH15","CIP2A"]
#html = urllib.request.urlopen("https://www.uniprot.org/").read()

#https://www.uniprot.org/uniprot/?query=ROBO1+Bos+taurus&sort=score

Entry = []
Entry_name = []
#Protrein = []
#Gene = []
#Organism = []
#Status = []
Biology = []

for i in genes:
    URL=str(i) #
    URL= "https://www.uniprot.org/uniprot/?query="+i+"+Bos+taurus&sort=score"
    uclient=urlopen(URL) 
    pagehtml=uclient.read()
    uclient.close()
    # convirtiendolo en formato soup 
    pagesoup=soup(pagehtml, "html.parser")
    
    
    c =pagesoup.find("table",{"class":"grid"})
    
    if c != None : 
        entry = c.findAll("td" , {"class":"entryID"})[0].find("a").text
        entry_name = c.findAll("td")[3].text
        Entry.append(entry)
        Entry_name.append(entry_name)
        
        url = "https://www.uniprot.org/uniprot/"+entry
        uclient=urlopen(URL) 
        pagehtml=uclient.read()
        uclient.close()
        # convirtiendolo en formato soup 
        pagesoup=soup(pagehtml, "html.parser")
        
        f =pagesoup.find("ul",{"class":"noNumbering biological_process"})  #cambiar porque sale none
        print(f)
        # Biological process
        #biology = f.find("ul", {"class":"content-status"}).find("a").text  #borre span , cambiar lo de dentro de class
        #Biology.append(biology)
    else : 
        Entry.append(" ")
        Entry_name.append(" ")
        #Biology.append(" ")

#print(Entry)
#print(Entry_name)
#print(Biology)
# Out:
# None
# None
# None
# None
# None
# None
